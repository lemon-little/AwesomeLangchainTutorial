# %% [markdown]
# # Deep Agents
# ## Quickstart
# ### Step 1: Install dependencies
# `uv add deepagents tavily-python`
# `pip install deepagents tavily-python`
# ### Step 2: Set up your API keys
# ```bash
# export ANTHROPIC_API_KEY="your-api-key"
# export TAVILY_API_KEY="your-tavily-api-key"
# ```
# ### Step 3: Create a search tool

# %%
import os
from typing import Literal
from tavily import TavilyClient
from deepagents import create_deep_agent
from utils import TAVILY_API_KEY

tavily_client = TavilyClient(api_key=TAVILY_API_KEY)

def internet_search(
    query: str,
    max_results: int=5,
    topic: Literal["general", "news", "finance"] = "general",
    include_raw_content: bool=False,
):
    """
    参数：
        query: str,查询句子
        max_results: int=5,返回搜索结果的最大数量
        topic: Literal["general", "news", "finance"] = "general",搜索主题
        include_raw_content: bool=False,是否返回原文
    return
        返回网页搜索
    """
    return tavily_client.search(
        query,
        max_results=max_results,
        include_raw_content=include_raw_content,
        topic=topic,
    )

# %% [markdown]
# ### Step 4: Create a deep agent

# %%
research_instructions = """你是一名专业研究员。你的工作是进行深入研究，然后撰写一份精彩的报告。
你可以使用互联网搜索工具作为收集信息的主要方式。
## `internet_search`
使用此工具对给定的查询进行互联网搜索。你可以指定要返回的最大结果数量(max_results)、主题(topic)以及是否应包含原始内容(include_raw_content)。"""

from utils import llm_modelscope

model = llm_modelscope()
agent = create_deep_agent(
    model=model,
    tools=[internet_search],
    system_prompt=research_instructions,
)

# %% [markdown]
# ### Step 5: Run the agent

# %%
result = agent.invoke({"messages": [{"role": "user", "content": "langgraph是什么?"}]})

# Print the agent's response
print(result["messages"][-1].content)

# %%
result
# Out:
# {'messages': [HumanMessage(content='langgraph是什么?', additional_kwargs={}, response_metadata={}, id='de155ca2-957e-43a9-b336-349f51eef1f8'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 5201, 'total_tokens': 5242, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'Qwen/Qwen3-30B-A3B-Instruct-2507', 'system_fingerprint': '', 'id': 'chatcmpl-f07891ee-4139-42eb-a811-ae9d262de998', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--71f9c613-6c21-4845-987a-0d91c86e79fd-0', tool_calls=[{'name': 'internet_search', 'args': {'query': 'langgraph是什么', 'max_results': 5, 'topic': 'general', 'include_raw_content': False}, 'id': 'call_506c2253854e4202923fff', 'type': 'tool_call'}], usage_metadata={'input_tokens': 5201, 'output_tokens': 41, 'total_tokens': 5242, 'input_token_details': {}, 'output_token_details': {}}),
#   ToolMessage(content='{"query": "langgraph是什么", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://blog.csdn.net/musicml/article/details/136441895", "title": "一文搞懂LangChain 新利器：LangGraph 原创 - CSDN博客", "content": "LangGraph 是一个有用于构建有状态和多角色的Agents 应用，它并不是一个独立于Langchain 的新框架，而是基于Langchain 之上构建的一个扩展库，可以与", "score": 0.99980134, "raw_content": null}, {"url": "https://juejin.cn/post/7330521875649708058", "title": "快速了解LangGraph - 稀土掘金", "content": "from langgraph.graph import StateGraph from typing import TypedDict, List, Annotated all_actions: Annotated[List[str], operator.add] graph = StateGraph(State) graph.add_node(\\"model\\", model) graph.add_node(\\"tools\\", tool_executor) from langgraph.graph import END graph.add_edge(\\"tools\\", \\"model\\") graph.add_conditional_edge( 我们使用 LangGraph 重新创建了标准的 LangChain AgentExecutor。它允许您使用现有的 LangChain 代理，同时更容易地修改 AgentExecutor 的内部结构。默认情况下，此图的状态包含了一些您在使用 LangChain 代理时应该熟悉的概念：`input`、`chat_history`、`intermediate_steps`\xa0和\xa0`agent_outcome`。 from typing import TypedDict, Annotated, List, Union from langchain_core.agents import AgentAction, AgentFinish from langchain_core.messages import BaseMessage intermediate_steps: Annotated[list[tuple[AgentAction, str]], operator.add] ## 聊天代理执行器 Chat Agent Executor from typing import TypedDict, Annotated, Sequence from langchain_core.messages import BaseMessage messages: Annotated[Sequence[BaseMessage], operator.add] 1. **强制调用工具**：当您总是希望代理首先调用工具时使用。适用于 Agent Executor 和 Chat Agent Executor。 2. **循环步骤中**：如何在调用工具之前添加循环步骤。适用于 Agent Executor 和 Chat Agent Executor。 3. **管理代理步骤**：用于添加处理代理可能采取的中间步骤的自定义逻辑（在步骤较多时非常有用）。适用于 Agent Executor 和 Chat Agent Executor。 4. **以特定格式返回输出**：如何使用函数调用使代理以特定格式返回输出。仅适用于 Chat Agent Executor。 5. **动态直接返回工具的输出**：有时您可能希望直接返回工具的输出。我们在 LangChain 中提供了一种简单的方法来实现这一点。但这会导致工具的输出始终直接返回。有时，您可能希望让 LLM 自行决定是否直接返回响应。仅适用于 Chat Agent Executor。 * 聊天代理执行器 Chat Agent Executor", "score": 0.9991704, "raw_content": null}, {"url": "https://www.53ai.com/news/langchain/2025051436094.html", "title": "一文了解LangGraph是什么？——构建智能体的新一代框架 - 53AI", "content": "* 工作+AI    业务+AI    53AI KM 公司介绍  渠道合作 预约演示 工作+AI 工作对话 内容创作 方案撰写 魔法菜单 业务+AI 微信分身 海外客服 官网客服 抖音客服 数字老师 数字督导 智能服务台 智能问数 智能审核 智能工单 企微跟进助手 智能报价 企微销售助手 应用智改 企微客服助手 53AI KM 行业案例 场景案例 前沿技术 Agent框架 行业应用 企业落地 公司介绍 渠道合作 首页   AI知识库   Agent框架   langchain * 官方文档：https://github.com/langchain-ai/langgraph LangChain v1.0 模型选型：静态还是动态？一文看懂 Agent 的正确打开方式 2025-11-18 LangChain v1.0正式版发布，5分钟快速上手实战 2025-11-06 2025-09-21 AI 不再“乱跑”：LangChain × LangGraph 打造可控多阶段智能流程 2025-11-03 LangChain V1.0 深度解析：手把手带你跑通全新智能体架构 2025-09-06 Spring AI Alibaba/Dify/LangGraph/LangChain 一文讲清四大AI框架怎么选 2025-09-12 AI Agent 软件工程关键技术综述 2025-07-05  【LangChain 团队重磅实测报告】多智能体架构揭秘：谁才是性能之王？ 首个落地案例！WEBTOON 用 LangGraph 构建故事理解 Agent，创作者 AI 时代的范式来了？ 内容创作   大模型技术   个人提效   langchain   llamaindex   多模态技术   RAG技术   智能客服   知识图谱   模型微调   RAGFlow   coze   Dify   Fastgpt   Bisheng   Qanything   AI+汽车   AI+金融   AI+工业   AI+培训   AI+SaaS   提示词框架   提示词技巧   AI+电商   AI面试   数字员工   ChatBI   知识管理   开源大模型   智能营销   智能硬件   智能化改造   AI+医疗   MaxKB 工作+AI 业务+AI", "score": 0.9989267, "raw_content": null}, {"url": "https://milvus.io/zh/blog/langchain-vs-langgraph.md", "title": "LangChain vs LangGraph：开发人员选择人工智能框架指南 - Milvus", "content": "LangGraph builds on top of LangChain with a graph-based architecture, which is better suited for stateful applications, complex decision-making, and multi-agent coordination. ## LangGraph: Your Go-To for Stateful Agent Systems LangGraph’s state management capabilities make it very suitable for building complex multi-turn conversation systems: LangGraph steps in when your application outgrows that linear model and requires state, branching, or multiple agents working together. * **Choose LangGraph** if you’re building multi-turn conversations, agent systems, or collaborative agent ecosystems where context and decision-making matter. Many production systems start with LangChain’s components (document loaders, vector store connectors ...
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 8473, 'total_tokens': 8570, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'Qwen/Qwen3-30B-A3B-Instruct-2507', 'system_fingerprint': '', 'id': 'chatcmpl-f59a00ee-46b9-409d-bd49-cd76add79eee', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--361a36bb-1a6d-473a-883c-fa3566c614c9-0', tool_calls=[{'name': 'write_todos', 'args': {'todos': [{'content': '根据搜索结果，整理 LangGraph 的核心定义、技术架构和主要用途', 'status': 'in_progress'}, {'content': '分析 LangGraph 与 LangChain 的关系及其在 AI 智能体开发中的定位', 'status': 'pending'}, {'content': '总结 LangGraph 的典型应用场景和优势', 'status': 'pending'}]}, 'id': 'call_3525fe6c8eb24b1ab7f06c', 'type': 'tool_call'}], usage_metadata={'input_tokens': 8473, 'output_tokens': 97, 'total_tokens': 8570, 'input_token_details': {}, 'output_token_details': {}}),
#   ToolMessage(content="Updated todo list to [{'content': '根据搜索结果，整理 LangGraph 的核心定义、技术架构和主要用途', 'status': 'in_progress'}, {'content': '分析 LangGraph 与 LangChain 的关系及其在 AI 智能体开发中的定位', 'status': 'pending'}, {'content': '总结 LangGraph 的典型应用场景和优势', 'status': 'pending'}]", name='write_todos', id='efc44c2b-93c5-4f1c-a7c4-2e2dff4f8aab', tool_call_id='call_3525fe6c8eb24b1ab7f06c'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 47, 'prompt_tokens': 8666, 'total_tokens': 8713, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'Qwen/Qwen3-30B-A3B-Instruct-2507', 'system_fingerprint': '', 'id': 'chatcmpl-92549cdb-c3ec-491b-a7a0-5b3eec376e9a', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--e3936f38-8b32-4c22-b8ad-0c02964698e4-0', tool_calls=[{'name': 'internet_search', 'args': {'query': 'LangGraph 技术架构 详细说明', 'max_results': 3, 'topic': 'general', 'include_raw_content': False}, 'id': 'call_2864f82da1ba4589b1f289', 'type': 'tool_call'}], usage_metadata={'input_tokens': 8666, 'output_tokens': 47, 'total_tokens': 8713, 'input_token_details': {}, 'output_token_details': {}}),
#   ToolMessage(content='{"query": "LangGraph 技术架构 详细说明", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://gist.github.com/JimLiu/ca25ba4e4fccac2b6a16270c8e82b11a", "title": "Gemini Fullstack LangGraph 技术架构详解.md - GitHub Gist", "content": "# JimLiu/**Gemini Fullstack LangGraph 技术架构详解.md** # Gemini Fullstack LangGraph 技术架构详解 这是一个基于 **LangGraph** 和 **Google Gemini** 的全栈 AI 研究助手应用。该系统能够根据用户的问题自动生成搜索查询，利用 Google Search API 进行网络研究，通过反思机制识别知识空白，并迭代优化搜索直到能够提供带有引用来源的完整答案。 graph TB A[用户输入问题] --> B[前端 React 应用] B --> C[LangGraph API] C --> D[Agent Graph 状态机] D --> E[生成查询节点] E --> F[并行执行多个搜索] F --> G[Web 研究节点] G --> H[反思节点] H --> I{知识是否充足?} I -->|否| J[生成后续查询] J --> F I -->|是| K[最终答案节点] K --> L[返回带引用的答案] L --> B G -.-> M[Google Search API] E -.-> N[Gemini 2.0 Flash] H -.-> O[Gemini 2.5 Flash] K -.-> O  def generate_query state OverallState config RunnableConfig -> QueryGenerationState# 使用 Gemini 2.0 Flash 生成初始搜索查询# 根据用户设置的努力级别生成 1-5 个查询 def web_research state WebSearchState config RunnableConfig -> OverallState # 使用 Google Search API 工具进行搜索 # 解析搜索结果并提取引用信息", "score": 0.8674071, "raw_content": null}, {"url": "https://blog.csdn.net/musicml/article/details/136441895", "title": "一文搞懂LangChain 新利器：LangGraph 原创 - CSDN博客", "content": "LangGraph 技术架构解读\u200b 把基于LLM 的任务（比如：RAG、代码生成等）细节用Graph 进行精确的定义（定义图的节点与边），最后基于这个图来编译生成应用。 在任务", "score": 0.8184036, "raw_content": null}, {"url": "https://cloud.tencent.com/developer/article/2551628", "title": "LangGraph架构解析：构建可扩展Agent的状态机引擎 - 腾讯云", "content": "*Agent* ✅ 循环图支持多轮思考与行动 ✅ 状态持久化实现断点续跑 ✅ 可视化调试降低维护成本 messages: Annotated[list[AnyMessage], operator.add]  # 消息自动累积 graph.add_node(\\"llm\\", self.call_openai)  # LLM节点 graph.add_node(\\"action\\", self.take_action) # 工具执行节点 def exists_action(state: AgentState): return len(state[\'messages\'][-1].tool_calls) > 0  # 检测工具调用 graph.add_conditional_edges( def _run(self, query: str): checkpoint = graph.get_state(message_id) graph.recover_state(checkpoint) def human_approve(state): * 简单场景：可直接使用LangChain Agent 如有侵权，请联系 cloudcommunity@tencent.com 删除。 agent 如有侵权，请联系 cloudcommunity@tencent.com 删除。 agent agent 在企业级 Agent 系统的应用中，AI 助手在处理复杂业务场景时，往往会做出“聪明但错误”的决策。这种现象不仅影响了系统的可靠性，还可能导致企业蒙受真金白银的损失。因此，如何在关键节点引入“人类专家”的精准干预，避免 AI 唱独角戏，成为了企业级 Agent 系统设计中的核心问题。 agent AI Agent 终结者 LangGraph！ agent agent 智能体框架：11 个顶级 AI Agent 框架！ agent 人工智能 Agent（智能体）彻底改变了软件开发者构建智能应用的方式。这些 AI Agent 框架提供了所需的基础设施、工具集和方法论，用以创建能够以最少的人工干预进行推理、规划并执行复杂任务的自主系统。 使用LangGraph构建你的第一个AI Agent-附完整代码 agent AI Agent 指的是有能力主动思考和行动的智能体，能够以类似人类的方式工作，通过大模型来“理解”用户需求，主动“规划”以达成目标，使用各种“工具”来完成任务，并最终“行动”执行这些任务。 LangGraph 作为 LangChain 的自然延伸，完美地填补了后者在构建复杂、动态的 AI 应用方面的空白。它为我们提供了一种全新的视角，让我们能够更轻松地创建智能代理，并将其应用于各种复杂的业务场景。\u200d LangGraph Agent 架构设计 agent AIOps系列 | Agent 入门实战 agent C/Python AI Agent 终结者 LangGraph！ 智能体框架：11 个顶级 AI Agent 框架！ 使用LangGraph构建你的第一个AI Agent-附完整代码 LangGraph Agent 架构设计 AIOps系列 | Agent 入门实战 c 语言", "score": 0.73299384, "raw_content": null}], "response_time": 0.89, "request_id": "1d4c1ff2-0ca5-49b3-a409-6135bf8cd515"}', name='internet_search', id='6d9a551f-bdb7-4108-b261-a5ad5de36f9e', tool_call_id='call_2864f82da1ba4589b1f289'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 9989, 'total_tokens': 10086, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'Qwen/Qwen3-30B-A3B-Instruct-2507', 'system_fingerprint': '', 'id': 'chatcmpl-9b92e733-8171-45b1-82ca-933bea308e47', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--cc381940-9bf5-47b2-9ddf-2c903d6b2442-0', tool_calls=[{'name': 'write_todos', 'args': {'todos': [{'content': '根据搜索结果，整理 LangGraph 的核心定义、技术架构和主要用途', 'status': 'completed'}, {'content': '分析 LangGraph 与 LangChain 的关系及其在 AI 智能体开发中的定位', 'status': 'in_progress'}, {'content': '总结 LangGraph 的典型应用场景和优势', 'status': 'pending'}]}, 'id': 'call_78366bc3f061413786b77e', 'type': 'tool_call'}], usage_metadata={'input_tokens': 9989, 'output_tokens': 97, 'total_tokens': 10086, 'input_token_details': {}, 'output_token_details': {}}),
#   ToolMessage(content="Updated todo list to [{'content': '根据搜索结果，整理 LangGraph 的核心定义、技术架构和主要用途', 'status': 'completed'}, {'content': '分析 LangGraph 与 LangChain 的关系及其在 AI 智能体开发中的定位', 'status': 'in_progress'}, {'content': '总结 LangGraph 的典型应用场景和优势', 'status': 'pending'}]", name='write_todos', id='21716bfe-3a10-4b33-b3f1-5f4173294952', tool_call_id='call_78366bc3f061413786b77e'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 47, 'prompt_tokens': 10182, 'total_tokens': 10229, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'Qwen/Qwen3-30B-A3B-Instruct-2507', 'system_fingerprint': '', 'id': 'chatcmpl-df871e17-e5b6-451e-b398-44df87f1b25e', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--39ddb150-74f1-4a1e-b3c4-1f54685d6f0a-0', tool_calls=[{'name': 'internet_search', 'args': {'query': 'LangGraph 典型应用场景 优势分析', 'max_results': 3, 'topic': 'general', 'include_raw_content': False}, 'id': 'call_3c1dad519f634997af4e2a', 'type': 'tool_call'}], usage_metadata={'input_tokens': 10182, 'output_tokens': 47, 'total_tokens': 10229, 'input_token_details': {}, 'output_token_details': {}}),
#   ToolMessage(content='{"query": "LangGraph 典型应用场景 优势分析", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.51cto.com/article/794181.html", "title": "LangGraph，知多少？ - 51CTO", "content": "这种功能非常适合需要人类专家进行干预和决策的应用场景，如医疗诊断、金融分析等。通过结合人类智慧和自动化处理，系统能够提供更高质量和更可靠的", "score": 0.9999722, "raw_content": null}, {"url": "https://blog.csdn.net/qq_51605551/article/details/148203573", "title": "LangChain03-图数据库与LangGraph 原创 - CSDN博客", "content": "2.2 图数据库的典型应用场景. 场景, 技术优势. 社交网络分析, 快速查找好友链、社区发现. 推荐系统, 基于用户-商品关系的协同过滤. 金融风控, 检测欺诈", "score": 0.9999485, "raw_content": null}, {"url": "https://www.cnblogs.com/smartloli/p/18276355", "title": "LangGraph实战- 哥不是小萝莉- 博客园", "content": "* 博客园 前段时间LangChain发布了LangGraph，它引起了很多关注。LangGraph 的主要优势在于它能够实现循环工作流，这对于在 LLM 应用程序中模拟类似代理的行为至关重要。本篇博客，笔者将从介绍 LangGraph 的功能和用例，强调它与典型的有向无环图 (DAG)工作流的区别，并讨论如何构建更具交互性和迭代性的基于 LLM 的系统。换句话说，就是更好的 AI 代理实现。 LangGraph 作为一个使用 LLM 构建有状态、多参与者应用程序的库，具有广泛的应用场景。以下是一些可能的应用领域： LangGraph 可以用于构建个性化的推荐系统，根据用户的兴趣、历史行为和上下文信息提供相关的建议。通过使用持久性，LangGraph 使推荐系统能够记住用户的偏好并随着时间的推移进行改进。 LangGraph 可以用于构建数据分析应用程序，如欺诈检测、异常检测或模式识别。通过使用流式处理支持，LangGraph 使这些应用程序能够实时处理和分析数据，并根据需要进行扩展。 LangGraph 的关键要素之一是其良好的状态管理系统。在 LangGraph 中，每次执行图都会启动一个状态，图内的节点会在处理过程中传递和修改该状态。此状态不仅仅是一组静态数据，而是由每个节点的输出动态更新的，然后影响循环内的后续操作。 LangGraph 允许开发人员构建应用程序，其中 LLM 可以根据新信息重新评估和修改其策略或响应，模仿更像人类的交互模式。 通过阅读论文《CHAIN-OF-TABLE: EVOLVING TABLES IN THE\xa0REASONING CHAIN FOR TABLE UNDERSTANDING》，我们可以知道该论文中介绍了一种使用一系列类似 SQL 的操作（包括选择、分组、排序等）来优化从结构不良的表格中提取数据的技术。通过将提取的数据插入到新列中，该方法显著增强了表格与 SQL、人工解释以及 LLM 处理的兼容性。 程序辅助推理试图通过生成和执行类似 SQL 的程序来解决这个问题，但仍然无法准确地解析姓名和国籍。 链表方法迭代地应用一系列表格操作，将表格转换为更适合查询的格式，使 LLM 能够准确地得出正确答案。 #  设置检查点 \' my_checkpoint \' \' my_checkpoint \' \' my_checkpoint \' 要启用 HITL，您可以在图中添加一个特殊的节点，该节点将等待人类输入。以下是如何在 LangGraph 中添加 HITL 节点的示例： #  添加一个 HITL 节点 G.add_node(lg.HitlNode) #  将 HITL 节点连接到其他节点  # ... 当图执行到达 HITL 节点时，它将暂停并等待人类输入。您可以使用以下代码提供输入： \' my_input \' 这将在名为 my\\\\_graph.png 的文件中生成图的可视化表示。您可以使用任何支持的图像格式，如 PNG、JPEG 或 SVG。 LangGraph 允许您使用图来表示应用程序的流程。图中的每个节点表示一个操作或决策点，边表示节点之间的连接。您可以使用 Python 代码来定义图的结构。   一旦您定义了图的结构，您需要实现节点的功能。每个节点可以执行任意的 Python 代码，包括与 LLM 或其他外部服务的交互。   #  提供输入数据 \' text \' \' 我喜欢吃披萨 \'} #  运行应用程序 G.run(inputs) #  打印结果 print LangGraph 为开发者提供了构建更智能化应用的工具，这些应用能够更好地反映人类思维过程和交互的动态性。随着我们不断探索和尝试 LLM（大型语言模型）的功能，LangGraph 等工具成为从静态、一次性交互转向连续、上下文感知对话和流程的理想选择。 博客园  \xa0©\xa0 2004-2025   ", "score": 0.99847525, "raw_content": null}], "response_time": 0.62, "request_id": "9a25835e-7928-4e71-88ba-1248e474b6f7"}', name='internet_search', id='b6846b66-c88a-47b0-8b5e-f39cfdaaf471', tool_call_id='call_3c1dad519f634997af4e2a'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 96, 'prompt_tokens': 11486, 'total_tokens': 11582, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'Qwen/Qwen3-30B-A3B-Instruct-2507', 'system_fingerprint': '', 'id': 'chatcmpl-a78cda9f-d784-4ee7-93bc-9a48cfd7bad0', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--0dbbe015-4ab3-4aaa-96b1-6462ff265bd1-0', invalid_tool_calls=[{'type': 'invalid_tool_call', 'id': 'call_02a4a3f17cd54571ba7514', 'name': 'write_todos', 'args': '{"todos": [{"content": "根据搜索结果，整理 LangGraph 的核心定义、技术架构和主要用途", "status": "completed"}, {"content": "分析 LangGraph 与 LangChain 的关系及其在 AI 智能体开发中的定位", "status": "completed"}, {"content": "总结 LangGraph 的典型应用场景和优势", "status": "in_progress"}]', 'error': 'Function write_todos arguments:\n\n{"todos": [{"content": "根据搜索结果，整理 LangGraph 的核心定义、技术架构和主要用途", "status": "completed"}, {"content": "分析 LangGraph 与 LangChain 的关系及其在 AI 智能体开发中的定位", "status": "completed"}, {"content": "总结 LangGraph 的典型应用场景和优势", "status": "in_progress"}]\n\nare not valid JSON. Received JSONDecodeError Expecting \',\' delimiter: line 1 column 235 (char 234)\nFor troubleshooting, visit: https://docs.langchain.com/oss/python/langchain/errors/OUTPUT_PARSING_FAILURE '}], usage_metadata={'input_tokens': 11486, 'output_tokens': 96, 'total_tokens': 11582, 'input_token_details': {}, 'output_token_details': {}})],
#  'todos': [{'content': '根据搜索结果，整理 LangGraph 的核心定义、技术架构和主要用途',
#    'status': 'completed'},
#   {'content': '分析 LangGraph 与 LangChain 的关系及其在 AI 智能体开发中的定位',
#    'status': 'in_progress'},
#   {'content': '总结 LangGraph 的典型应用场景和优势', 'status': 'pending'}],
#  'files': {}}

# %%
for msg in result["messages"]:
    msg.pretty_print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for msg in result["messages"]:
#       2     msg.pretty_print()
#
# NameError: name 'result' is not defined
